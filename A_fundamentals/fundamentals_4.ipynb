# %% [markdown]
# *Much of this notebook was adapted from [Kate Follette's course](https://github.com/kfollette/AST200-Spring2020), which itself adapted material from [Mark Krumholz's public course notes](https://sites.google.com/a/ucsc.edu/krumholz/teaching-and-courses/)*

# %% [markdown]
# # Python Fundamentals: Notebook # 4
#
# ## Contents
#
# 1. Lists
#     * Defining lists
#     * Indexing lists
#     * Slicing lists
# 2. Arrays
#     * Defining arrays
#     * Array manipulation
#     * Multidimensional arrays
#     * Array attributes

# %% [markdown]
# # 1. Lists
#
# ## 1.1 Defining Lists

# %% [markdown]
# Another useful type of python object is called a list, and lists are defined with square brackets. Lists are slightly different from arrays, which will be discussed in the next section, but many operations work on both. Lists can have objects with different types stored inside them.

# %%
A = ["I","am","a","list","of","Astronomers","Hubble","Drake","Jump-Cannon","Payne-Gaposhkin", "Bell-Burnell"]
A

# %%
B=["I","am","a","list","of","strings","and","numbers",3.14,42,-10,1]
B

# %% [markdown]
# ## Exercise 4a
# -------------
#
# Operators are pretty useful for comparing lists. Add a comment to each of the cells below describing what the test is and why it is true or false.

# %%
A is B

# %%
1 in B

# %%
"b" not in B

# %% [markdown]
# ## 1.2 Indexing a List
#
# We can access a specific element in a list by refering to its `index`, i.e. its position in the list.
#
# Importantly, lists in python are numbered starting from *`zero`* as illustrated in the following table for the list `A`:
#
# | Index     | Element            |
# |-----------|--------------------|
# | 0         |  "I'               |
# | 1         |  "am"              |
# | 2         |  "a"               |
# | 3         |  "list"            |
# | 4         |  "of"              |
# | 5         |  "Astronomers"     |
# | 6         |  "Hubble"          |
# | 7         |  "Drake"           |
# | 8         |  "Jump-Cannon"     |
# | 9         |  "Payne-Gaposhkin" |
# | 10        |  "Bell-Burnell"    |
#
#
# So the first item in a list is accessed using an index of `[0]`
#
# For example, in the cells below, we can see that
#
# `A[0] is "I"`
#
# and
#
# `A[1] is "am"`

# %%
A[0]

# %%
A[1]

# %% [markdown]
# To extract the *last* element in a list, you can either specify the correct value (which will be equal to the length of the list minus 1), *or* as a convenience you can just specify `[-1]` and python will interpret this to mean the last item in the array.

# %%
print( "len(A)=", len(A))
print( A[10] )
print( A[len(A)-1] )
print( A[-1] )

# %% [markdown]
# You can also get the second-to-last entry by specifying `[-2]`, and so on.
#
# I.e. when you use negative indices, python switches to use the following assignment for list `A`
#
# | Index     | Element            |
# |-----------|--------------------|
# | -11       |  "I'               |
# | -10       |  "am"              |
# | -9        |  "a"               |
# | -8        |  "list"            |
# | -7        |  "of"              |
# | -6        |  "Astronomers"     |
# | -5        |  "Hubble"          |
# | -4        |  "Drake"           |
# | -3        |  "Jump-Cannon"     |
# | -2        |  "Payne-Gaposhkin" |
# | -1        |  "Bell-Burnell"    |

# %%
print(A[-1])
print(A[-2])
print(A[-3])

# %% [markdown]
# ## Exercise 4b
# -------------
#
# In the cell below, extract the words `"strings"` from list `B` by entering the correct *positive* index in the square brackets

# %%
B[]

# %% [markdown]
# ## Exercise 4c
# -------------
#
# In the cell below, extract the words `"strings"` from list `B` by entering the correct *negative* index in the square brackets

# %%
B[]

# %% [markdown]
# ## 1.3 List Slicing: Sub-sections of Lists
#
# It is often useful to be able to extract just a section of a list; E.g. the first 10 items in a list, or the last half of a list, etc etc.
#
# The way we do this is refered to as "list slicing", and has the following generic specification:
#
# `Lst[ Initial : End : IndexJump ]`
#
# If Lst is a list, then the above expression returns the portion of the list from index Initial to index End, at a step size IndexJump.
#
#
#
#  - If no value for `Initial` is supplied, it defaults to a value of `0`.
#  - If no value for `End` is supplied, it defaults to a value of `len(Lst)-1`.
#  - If no value for `IndexJump` is supplied, it defaults to a value of `1`.
#
# Note that the `End` index is **exclusive**, not inclusive, so the ending index element is not included.
#
# E.g., to extract the first 5 elements of list `A`, we can do any of the following...

# %%
print( A[0:5:1] )
print( A[:5:1] )
print( A[:5] )

# %% [markdown]
# To extract elements with indexes 2,3 & 4 we can do either of the following

# %%
print( A[2:4:1] )
print( A[2:4] )

# %% [markdown]
# To extract every 2nd element we can set `IndexJump = 2`

# %%
print( A[0::2] )

# %% [markdown]
# We can also set `IndexJump` to be *negative*
#
# If we do so, then python switches to the *negative indexing* described above.
# Normally, slicing with a positive step size moves from left to right, but with a negative step size, it goes from right to left.
#
# If we set `IndexJump = -1 `, and leave the start and end unspecified, then effect is the start at the end/right, and move backwards in steps of size one, thus *reversing* the list ...

# %%
print( A[::-1] )

# %% [markdown]
# And in the cell below, we can commence from the second-to-last position, and then print-out every other item in the list ...

# %%
print( A[-2::-2] )

# %% [markdown]
# ## Exercise 4d
# -------------
#
# In the cell below, use list-slicing to create the following two lists:
# 1. A list named `animals` that contains every-other entry in `unique_words`, starting from index=1
# 2. A list named `fruits` that contains a *reversed* list of every-other entry in `unique_words`, starting from index=-2

# %%
unique_words = [
    "apple", "antelope", "banana", "bear", 
    "cherry", "baboon", "date", "elephant", 
    "fig", "buffalo",  "peach", "leopard", 
    "coconut", "badger", "grape","butterfly", 
    "kiwi", "skunk", "melon", "bat"
]

# %% [markdown]
# # 2. Arrays
#
# ## 2.1 Defining Arrays
#
# The variables we have dealt with so far are fairly simple. They represent single values. However, for scientific or numeric purposes we often want to deal with large collections of numbers. The basic tool for doing this is an *array.* Arrays are not part of the core python language, but they are part of a very commonly used code module called numpy.

# %%
import numpy

# %% [markdown]
# Once loaded, you can take advantage of any numpy function (like the "type" function that is part of the python core language) by typing numpy.functionname. For example, the square root (sqrt) function:

# %%
numpy.sqrt(16)

# %% [markdown]
# As we will use numpy a lot, it is convenient to import it under a shorter pseudonym, as below. This can be anything really, but it's easiest to use something that will be easy to remember. The standard short name for numpy is np

# %%
import numpy as np

# %%
np.pi

# %% [markdown]
# OK back to arrays, which besides built in mathematical functions like square roots, exponentials, etc., are one of the most common uses of the numpy library.
#
# Formally, an array is a collection of objects that all have the same type: a collection of integers, or floats, or booleans, or anything else. In the simplest case, these are simply arranged into a numbered list, one after another. Think of an array as a box with a bunch of numbered compartments, each of which can hold something. For example, here is a box with eight compartments.
#
# ![](fundamentals_4_array_fig1.png "A Blank Array")
#
# In python, and in many (but not all) computer languages, we start counting at 0, so that the first compartment is compartment 0, the second is compartment 1, and so forth. We can create an array in python in a few different ways. One is just to explicitly list the elements we want it to contain. The syntax is straightforward:

# %%
x = np.array([10,11,12,13,14,15,16,17])

# %% [markdown]
# Defining the array as above, puts the values we specified into the appropriate compartments in the box.
# Similar to lists, the array `x` can be thought of as follows:
#
# ![](fundamentals_4_array_fig2.png "A Populated Array")

# %% [markdown]
# Note that there is no output in the cell above, because again we are defining a variable, and we do not explicitly ask for it to be printed.
#
# You can see it and check the stored values by typing the variable name, as in the cells below.

# %%
x

# %% [markdown]
# If you type the array you've defined, you'll also see that is is a special new kind of numpy variable.

# %%
type(x)

# %% [markdown]
# *For those of you who have used python before, note that an array is different from a list (defined simply with square brackets, e.g. a = [1,2,3,4,5]). There are some subtle differences between the two, but the principal practical difference is that you can do arithmetic operations on all entries in an array simultaneously , but you cannot do this for lists (you have to do it item-by-item for lists).*
#
# In this case the array we have created is an array of integers, since each of the entries we specified was an integer. If one of them had been a floating point number (for example if we changed the 10 to 10.0), then the array would have been an array of floats, meaning that EACH entry would have been made a float. Remember the rule: every element of an array must have the same type, so if you make one them into a float, then all of them will be floats.
#
# Another way to create an array is to simply give the number of elements, and set them all to be zero initially. This can be done with the `zeros` command:

# %%
y = np.zeros(8)
y

# %% [markdown]
# The `zeros` command creates an array with the specified number of elements, and sets them all to zero. Note that they are all floats (you can tell from the decimal point after each zero), which is what the `zeros` command creates by default. If you want some other data type, you can specify it using an option built into the `zeros` command called "dtype", which allows you to specify the data type you want:

# %%
yint = np.zeros(8, dtype='int')
yint

# %% [markdown]
# <div class=sidebar>
#
# ### Sidebar - Function options/keywords
# -----------------------
#
# Say you know you want to use the numpy function `zeros` to define an integer array, but you can't remember the syntax for the option, its name, etc. To find out what is available, you can use one of the special functions of a Jupyter code cell by following the function name with a question mark, as below:

# %%
np.zeros?

# %% [markdown]
# <div class=sidebar>
# This opens the function's "docstring" in a separate pane, which you can close at will once you're done with it. This docstring will list the available options (keywords), and will often give examples of their usage. A good descriptive docstring is a very important part of writing functions, as we will discuss in detail next week.

# %% [markdown]
# The analogous numpy function `ones` creates an array where every element is 1. Here too, the default data type is float.

# %%
z = np.ones(8)
z

# %% [markdown]
# A third and very useful way to create arrays is using the `arange` command. This creates an array with specified starting and ending values, and with a specified step size. For example:

# %%
w = np.arange(0,16,2)
w

# %% [markdown]
# The first argument to arange is the starting value, the second is the ending value (notice that this is exclusive, not inclusive, so in the above example the array z does not contain the number 16), and the final entry is the step size.
#
# Again, because all the entries were integers, the array consists of integers. If one of them had been a float, the array would have contained floats.
#
# Note that one can omit the final entry in arange, in which case the step size defaults to a value of 1. One can also omit the second entry (for example just say *arange(8)*), in which case the array created starts with 0 as the first entry, has a step size of 1, and contains the number of entries specified in the argument. Thus *arange(8)* creates an array that contains the numbers 0 to 7.

# %%
np.arange(8)

# %% [markdown]
# ## 2.2 Array Manipulation
#
# So how do we deal with arrays? What can we do with them?
#
# ### 2.2.1 Array Indexes
#
# One way to deal with an array is to interact with its elements individually.
#
# This is done in the same way as described for list indexing in section 1.2 above.

# %%
x[2]

# %%
type(x[2])

# %%
x[2]*2

# %%
x[2] = 32
x

# %% [markdown]
# In the examples above, we printed out the value stored in compartment number 2 of the array x, we checked the type of value stored in that compartment (in this case, a 64 bit integer), we multiplied it by 2 to get a result, and then we assigned a different value (32) to that compartment, erasing its original value.

# %% [markdown]
# ### 2.2.2 Array Slicing
#
# We can access sub-sections of an array by using the same "slicing" methods described for lists in section 1.3 above.

# %%
x[1:4]

# %%
x[:4]

# %%
x[4:]

# %% [markdown]
# As with lists, we can also specify that we want not every element, but every 2nd element, or every 3rd element, etc., within our specified range. For example:

# %%
x[::2]

# %% [markdown]
# And as with lists, we can also use negative indexing:
#
# ![](fundamentals_4_array_fig3.png "Array Indexing")

# %%
x[:-2]

# %% [markdown]
# ### 2.2.3 All-Array Operations
#
# The really useful thing about arrays is that one can perform mathematical operations or assignments to multiple elements of an array at once.
#
# Several examples are given below. Execute the cell, examine the output, and make sure you understand what happened to the array before moving on.

# %%
x-10

# %%
x[1:4]-10

# %%
x[1:4]=-10
x

# %%
x[::2]=5
x

# %% [markdown]
# One can also do operations involving two arrays with the same number of elements. These operations are performed element by element. For example:

# %%
arr1 = np.arange(10)

# %%
arr2 = np.arange(10)*2

# %%
arr1 + arr2

# %% [markdown]
# In this example, x is filled with 0, 1, 2, ... 9, and y is filled with 0, 2, 4, ... 18. When we add them, we get 0, 3, 6, ... 27. The arrays are added together one element at a time, producing an output array that has the same number of elements as the two inputs.
#
# These capabilities for manipulating multiple elements at once are very convenient for manipulating large groups of numbers.

# %% [markdown]
# ## Exercise 4e
# -------------
#
# 1. Create a *list* (not an array) named `a_list` containing the integers 0 to 10 inclusive.
# 2. Try to multiply `a_list` by 2 by executing `a_list*2`; describe what happens.
# 3. Use jupyter's "?" functionality to find out about the numpy "asarray" function.
# 4. Use the numpy "asarray" function and the list `a_list`, and create an **array** named `a_arr` whose entries are the same as the entries of `a_list`.
# 5. Print `a_list` and `a_arr`. Describe the difference.
# 6. Print `type(a_list)` and `type(a_arr)`. Describe the difference.

# %% [markdown]
# ## 2.3 Multidimensional arrays
#
# The arrays we've played with so far are one-dimensional, meaning that they look like a series of boxes laid out in a line. However, arrays can be multidimensional as well. For example:

# %%
x2d = np.array([[10,11,12,13], [20,21,22,23], [30, 31, 32, 33]])
x2d

# %% [markdown]
# You can think of this as a box with multiple rows of compartments:
#
# ![](fundamentals_4_array_fig4.png "2-D Array")
#
#
# The format for indexing a 2D NumPy array is **array[row_index, column_index]**.
#
#  - Index [0, 0] maps to the element 10.
#  - Index [0, 1] maps to the element 11.
#  - Index [0, 2] maps to the element 12.
#  - ...
#  - Index [1, 0] maps to the element 20.
#  - Index [1, 1] maps to the element 21.
#  - ...
#
# So, in the context of a 2D Python NumPy array, the first index specifies the row and the second index specifies the column, which together point to the specific element at that position in the array.

# %% [markdown]
# Execute each of the cells below and make sure you understand what it is doing.

# %%
x2d[0,0]

# %%
x2d[1,2]

# %%
print("x2d[0, :]     = ", x2d[0, :])
print("x2d[0, 0:4:1] = ", x2d[0, 0:4:1])
print("x2d[0, 0::1]  = ", x2d[0, 0::1])
print("x2d[0, ::1]   = ", x2d[0, ::1])
print("x2d[0, ::]    = ", x2d[0, ::])

# %% [markdown]
# ***The cells above and below are designed to re-emphasize/reiterate that the 'slice' notation (described above in the context of lists) can achieve the same results in a number of different ways. ***
#
# This is because the slice indicees default to certain values if they are not supplied: as supplied above ...
#  - If no value for `Initial` is supplied, it defaults to a value of `0`.
#  - If no value for `End` is supplied, it defaults to a value of `len(Lst)-1`.
#  - If no value for `IndexJump` is supplied, it defaults to a value of `1`.

# %%
print("x2d[:,1]     = ", x2d[:,1])
print("x2d[0:3:1,1] = ", x2d[0:3:1,1])

# %%
x2d[:,1:4]

# %% [markdown]
# The zeros and ones commands also work in multiple dimensions.
#
# You just have to specify the size of each dimension:

# %%
y2d = np.zeros((3,7))
y2d

# %% [markdown]
# Arrays can of course have more than two dimensions as well. In fact, there is no limit to how many dimensions they can have.
#
# You can also do useful things like find the maximum and minimum values in arrays, and their means and totals:

# %%
np.amin(x2d)

# %%
np.amax(x2d)

# %%
np.mean(x2d)

# %%
np.sum(x2d)

# %% [markdown]
# ## 2.4 Array Attributes
#
# Much of astronomy is image manipulation, and images are essentially very large arrays (large enough that it no longer becomes practical to print them to the window as we've been doing here). Upon importing an array (e.g. an astronomical image) or after manipulating it, you will often want to know some of its basic properties. There are several built-in python functions that are particularly useful for this, and you call them by typing the variable name + the operator name, as below.

# %%
x2d.ndim

# %%
x2d.shape

# %%
x2d.size

# %%
x2d.dtype

# %% [markdown]
# ## Exercise 4f
#
# -------------
#
# Follow the steps below.
#
# 1) Create a 10 x 10 numpy integer array and set it equal to a variable. Print it to output once you're done populating it as described below.
#   * make the first row contain the numbers 10 through 100 in steps of 10
#   * make each element in the second row equal to 5 more than the first row
#   * row 3 = row 1\*10
#   * row 4 = (row 1)$^2$
#   * row 5 = $\sqrt{row 2}$
#   * row 6 = 3\*row 3-2\*row 4
#   * row 7 = alternating 0s and 1s, starting with 0
#   * row 8 = all 8s except the third from last element, which is -8
#   * row 9 = 1, 1/2, 1/3, 1/4, ...
#   * row 10 = all elements are 42 except for the first 4, which are 0
#
# 2) copy this array into a new variable, then in the new array, multiply each number in the third column by two
# 3) set the second to last element in each row of the new array equal to 0, and print the new array as output
# 4) multiply your original array by this new array and print the output

# %%
#execute this cell before beginning so that the array will be more readable when you print it
np.set_printoptions(precision=3, suppress=True, linewidth=120)

# %%
#make array here (feel free to add more cells and do it step by step)

# %% [markdown]
# In addition to the capabilities we've just gone through, arrays can do far more. For a full list, see http://docs.scipy.org/doc/numpy/reference/arrays.ndarray.html.
