# %% [markdown]
# *Much of this notebook was adapted from [Kate Follette's course](https://github.com/kfollette/AST200-Spring2020), which itself adapted material from exercises put together by [Jake Vanderplas](http://www.vanderplas.com).

# %% [markdown]
# # Fundamentals 7: Summary Exercises

# %% [markdown]
# Let's put a few of the things that you've learned so far together.
#
# ### Exercise 1
#
# The two lists `veg_nos` and `veg_names` from the notebook `fundamentals_5` have been copied into the cell below.
#
# Write a new function that satisfies the requirements below.
#
# 1. Write a function that accepts the name of a vegetable as an input variable.
# 2. Test whether the input name is in the list `veg_names` (use a membership operator)
# 3. Find the index of the list `veg_names` where it is equal to that input number (use the list method "index" where listname.index(element) returns the index of element in listname. Play around with simple lists that you define if you don't know what I mean here).
# 4. Use the index found in 3. to extract the number of required vegetables from `veg_nos`, and print "We need to buy {veg_num} {veg_name}"
# 5. If the input is not a string, print "Only strings are welcome here"
# 6. If *input* is a string that is not in `veg_names`, print "So sorry. I don't need any {input}"
#
#
# Below your function in one cell each, insert a test statement that demonstrates each of the new capabilities.

# %%
veg_nos = [10,2,6,6,2,5,25,15,2,4,3,3,100,1,2]
veg_names=["Tomatoes","Eggplant","Onions",
            "Potatoes","Cucumbers","Beets",
            "Scallions","Carrots","Artichokes",
            "Parsnips","Shallots","Garlic",
            "Peas","Spinach","Swiss Chard"]
