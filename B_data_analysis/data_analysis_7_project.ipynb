# %% [markdown]
# # Data Analysis 7: Project
#
#
# This `data_analysis_7_project` notebook defines the required project for the data analysis section of 422.
#
# In this project you will create a module named `data_project` that contains the functions listed below:
#
# ```python
# data_project.py
#     read_and_standardize
#     exp_decay_func
#     fit
#     plot
#     run_project
#     ```
#
# ## Project Specification
# The overall goal of the project is to
#  - read in some exponential decay data from three files named 'decay1.csv', 'decay2.csv' & 'decay3.csv';
#  - fit each set of data with an exponential decay model
#  - plot the data and the fitted curves all on the same figure
#
# In detail, you should ...
# 1. Create a function named `read_and_standardize` that will:
#  - Read the data from a single file into a single dataframe
#  - Prompt the user (using the `input` method from "fundamentals_8.ipynb") to say which field seems to contain "time" information and which field seems to contain information on "counts"
#  - Change the name of the dataframe fields to have standardized names ("time" & "counts")
#  - Return the standardized dataframe
# 2. Create a function named `exp_decay_func(x, a,b,c)` that will return `a * np.exp(-b * x) + c`
# 3. Create a function named `fit` that will:
#  - use `exp_decay_func` and `curve_fit` to fit the data in a dataframe that contains "time" and "counts" fields
#  - return the best fit coefficients
# 4. Create a function named `plot` that will:
#  - take as arguments a list of dataframes and a corresponding list of fitted coefficients
#  - plot all of the dataframes and fits on a single plot
#  - include a legend that shows the values of the fitted coefficients
#  - save the plot to a file named 'project.png'
# 5. Create a function named `run_project` that will:
#  - Run `read_and_standardize` on all three files named 'decay1.csv', 'decay2.csv' & 'decay3.csv'
#  - Pass all three resultant dataframes to `fit`
#  - Pass all three dataframes and all three sets of fitted coefficients to `plot`
# 6. Put everything in a module named `data_project.py`
# 7. Import `data_project` and run the `run_project` function

# %%
# Import project (using reload to help while developing/debuggin)
import importlib
import data_project
importlib.reload(data_project)
# Run project
data_project.run_project()
