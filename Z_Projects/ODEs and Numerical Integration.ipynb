# %% [markdown]
# # Euler
#
#  - Euler: python notebooks: https://pythonnumericalmethods.berkeley.edu/notebooks/chapter22.03-The-Euler-Method.html
#  - Youtube videos: there are many ... https://www.youtube.com/watch?v=cdUpAuGTIfE
#  - https://medium.com/@vikramsetty169/solving-second-order-odes-using-eulers-method-python-cb77abb89efe
#
# # Runge-Kutta
#
#  - Very good notebook with worked examples: https://perso.crans.org/besson/publis/notebooks/Runge-Kutta_methods_for_ODE_integration_in_Python.html
#  - Wikipedia theory: https://en.wikipedia.org/wiki/Runge%E2%80%93Kutta_methods
#
#
#  ## NBody
#   - Application of Runge-Kutta to NBody Integration: https://prappleizer.github.io/Tutorials/RK4/RK4_Tutorial.html
